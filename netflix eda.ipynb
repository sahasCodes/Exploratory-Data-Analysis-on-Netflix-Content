# %%
#Importing libraries
import numpy as np
import pandas as pd
print("Import Successful")
# Out:
# Import Successful

# %%
#Importing dataset
df=pd.read_csv(r"C:\Users\parab\Desktop\secret\Portfolio projects\Netflix eda\netflix_titles.csv")
print("Data Imported Successfully 🚀")
# Out:
# Data Imported Successfully 🚀

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
#Some stats/info of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
#description of the data
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
#Knowing the columns name in the dataset
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
#Shape of the dataset
df.shape
# Out:
# (8807, 12)

# %%
#Knowing the number of years present in data
df["release_year"].value_counts()
# Out:
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
#         ...
# 1959       1
# 1925       1
# 1961       1
# 1947       1
# 1966       1
# Name: release_year, Length: 74, dtype: int64

# %%
df["type"].value_counts()
# Out:
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %%
#Checking for null values
pd.DataFrame(df.isnull().sum())
# Out:
#                  0
# show_id          0
# type             0
# title            0
# director      2634
# cast           825
# country        831
# date_added      10
# release_year     0
# rating           4
# duration         3
# listed_in        0
# description      0

# %%
#Replacing NAN  values in rating column with TV-MA
df["rating"].replace(np.nan,"TV-MA",inplace=True)

# %%
#Replacing NAN values in country column with United States
df["country"].replace(np.nan,"United States",inplace=True)

# %%
#Replacing column name "listed_in" to "genre"
df.rename(columns={"listed_in":"genre"},inplace=True,errors='raise')

# %%
#EDA

# %%
import seaborn as sns
import matplotlib 
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set_style('darkgrid')

# %%
df["release_year"].value_counts().mean()
# Out:
# 119.01351351351352

# %%
plt.title("Netflix Contents Release per Year")
df["release_year"].value_counts().plot.barh(figsize=(30,20),color="#E50914")
plt.show()

# %%
#TV Shows VS Movies on Netflix
plt.figure(figsize=(10,5))
plt.title("TV Shows vs Movies on Netflix")
sns.barplot(x=df['type'],y=df.index)
plt.show()

# %%
plt.title("TV Shows vs Movies on Netflix")
df['type'].value_counts().plot.pie(autopct='%1.1f%%',figsize=(15,10))
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.title('netflix Ratings distribuaton')
sns.countplot(x='rating',data=df)
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.title("Netflix ratings distribution seprated by type of release")

color_labels = df['rating'].unique()

rgb_values = sns.color_palette("Set2",6)

color_map=dict(zip(color_labels,rgb_values))

sns.countplot(x='rating',data=df,hue="type",palette=df['rating'].map(color_map))
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.title("Top 5 Countries")
colors = sns.color_palette("husl", 9)
df["country"].value_counts().nlargest(n=5).plot.pie(autopct='%1.1f%%',figsize=(15,10), colors=colors)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title("Top 5 countries")
df["country"].value_counts().nlargest(n=5).plot.barh(figsize=(15,10),color="#E50914")
plt.show()

# %%
plt.figure(figsize = (15,8))
plt.title('Top 5 Netflix country distribution seperated by type of release')
sns.countplot(x='country', data=df, hue='type', order=df.country.value_counts().iloc[:5].index, color="#E50914")
plt.show()

# %% [markdown]
# Question and Answer

# %% [markdown]
# Q1:What is the proportionality between the Genre of movies and TV Shows?

# %%
plt.figure(figsize=(15,8))
plt.title('Top 10 Genres for Movies')
colors=sns.color_palette('pastel')[0:11]
df[df["type"]=="Movie"]["genre"].value_counts()[:10].plot(kind='barh', color=colors)
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.title('Top 10 Genres for Movies')
colors=sns.color_palette('pastel')[0:11]
df[df["type"]=="TV Show"]["genre"].value_counts()[:10].plot(kind='barh', color=colors)
plt.show()

# %% [markdown]
# Q2: Who are the top 10 actors on Netflix?

# %%
#Fillinf NAN with values
df['cast']=df['cast'].fillna("No cast mention")

#Creating a Data frame to store the filtered cast(i.e Actors)

cast_df=pd.DataFrame()
cast_df=df["cast"].str.split(',',expand=True).stack()
cast_df=cast_df.to_frame()
cast_df.columns=["Actor"]
actors=cast_df.groupby(['Actor']).size().reset_index(name='Total Content')
actors=actors[actors.Actor != 'No cast mention']

#Sorting the top 10 

actors=actors.sort_values(by=['Total Content'],ascending=False)
top_actors=actors.head(10)
top_actors=top_actors.sort_values(by=['Total Content'])
x= top_actors['Actor']
y=top_actors['Total Content']

#Ploting the Bar graph
plt.style.use("fivethirtyeight")
plt.figure(figsize = (17,8))
plt.title('Top 10 Actors')
sns.barplot(x = x, y = y)
plt.show()

# %% [markdown]
# Q3: Does Netflix upload more Movies or TV shows

# %%
plt.figure(figsize=(15,8))

plt.plot(df[df['type']=="TV Show"].groupby("release_year")['type'].count(),color="#E50914",linewidth=4)
plt.plot(df[df['type']=="Movie"].groupby("release_year")['type'].count(),color="black",linewidth=4)

plt.xlabel("Year")
plt.ylabel("Titles Added")
plt.title("Movies VS TV Shows released on Netflix per Year")
plt.legend(['TV Shows','Movies'])
plt.show()

# %% [markdown]
#  The chart shows the historical trends in the release of TV Shows and movies on Netflix.
# Looking at the lines representing TV shows and movies, both show an upward trajectory, suggesting an overall increase in the quantity of content being added to Netflix's library.
#
# Specifically, the line representing TV shows red appears to have a steeper incline, indicating a relatively higher rate of growth compared to movies,represented by the black line. This suggests that Netflix has been focusing on expanding its TV show offerings more rapidly than its movie catalog.
#
# Overall, the trend suggests that Netflix has been consistently adding more TV shows and movies to its platform over time, reflecting the company's efforts to diversify and expand its content library to cater to a wide range of viewer preferences.
